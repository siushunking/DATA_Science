# %%
# Multiple Linear Regression
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('50_Startups.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 4].values

# %%
city = dataset.iloc[:, 3].values
city = pd.get_dummies(city)
city = city.iloc[:,0:2].values
X = dataset.iloc[:, 0:3].values
X = pd.DataFrame(X)
city = pd.DataFrame(city)
X = pd.concat([X, city], axis=1)
X.columns = ['r&d','admin','marketing', 'city1', 'city2']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
y_pred, y_test
# Out:
# (array([103015.20159776, 132582.27760831, 132447.73845184,  71976.09851266,
#         178537.4822107 , 116161.24230157,  67851.69209689,  98791.73374679,
#         113969.43533008, 167921.06569569]),
#  array([103282.38, 144259.4 , 146121.95,  77798.83, 191050.39, 105008.31,
#          81229.06,  97483.56, 110352.25, 166187.94]))

# %%
# !pip install statsmodels

# %%
# Building the optimal model using Backward Elimination
# 檢查p-value 將highest p-value && p>SL(0.05) 

import statsmodels.api as sm
X_train = np.append(arr = np.ones((40, 1)).astype(int), values = X_train, axis = 1)
X_opt = X_train [:, [0, 1, 2, 3, 4, 5]]
regressor_OLS = sm.OLS(endog=y_train, exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.943
# Method:                 Least Squares   F-statistic:                     129.7
# Date:                Thu, 28 Apr 2022   Prob (F-statistic):           3.91e-21
# Time:                        16:12:34   Log-Likelihood:                -421.10
# No. Observations:                  40   AIC:                             854.2
# Df Residuals:                      34   BIC:                             864.3
# Df Model:                           5
# Covariance Type:            nonrobust
# ...

# %%
X_opt = X_train [:, [0, 1, 2, 3, 4, 5]]
regressor_OLS = sm.OLS(endog=y_train, exog=X_opt).fit()
regressor_OLS.summary()

# %%
X_opt = pd.DataFrame(X_opt)
X_opt.columns = ['b','r&d','admin','marketing', 'city1', 'city2']

# %%
X_opt = X_train [:, [0, 1, 2, 3, 5]]
regressor_OLS = sm.OLS(endog=y_train, exog=X_opt).fit()
regressor_OLS.summary()

# %%
X_opt = X_train [:, [0, 1, 3]]
regressor_OLS = sm.OLS(endog=y_train, exog=X_opt).fit()
regressor_OLS.summary()

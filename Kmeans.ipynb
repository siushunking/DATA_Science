# %%
import pandas as pd

# %%
df = pd.read_csv("/content/HAR_train.csv")

# %%
print("shape: " + str(df.shape))

# %%
labels = df["activity"]
x = df.drop(["rn","activity"], axis=1)

# %%
label_keys = labels.unique()

# %%
label_keys
# Out:
# array(['STANDING', 'SITTING', 'LAYING', 'WALKING', 'WALKING_DOWNSTAIRS',
#        'WALKING_UPSTAIRS'], dtype=object)

# %%
label_keys = labels.unique()

# %%
x.isnull() #false equal nit null

# %%
temp = pd.DataFrame(x.isnull().sum())
temp.columns = ['sum']

# %%
str(len(temp[temp['sum'] > 0]))
# Out:
# '0'

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x = scaler.fit_transform(x)

# %%
from sklearn.cluster import KMeans
wcss = [] #計算 距

# %%
for i in range(1,11):
   kmeans = KMeans(n_clusters=i,init="k-means++", random_state=0).fit(x)
   wcss.append(kmeans.inertia_)

# %%
import matplotlib.pyplot as plt
plt.plot(range(1,11), wcss) #x y
plt.title('the elbow methods')
plt.xlabel('number of cluster')
plt.ylabel('wcss')
plt.show()

# %%
kmeans = KMeans(n_clusters=3,init="k-means++", random_state=0).fit_predict(x)

# %%
pd.DataFrame(kmeans)
# Out:
#       0
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
# ...  ..
# 3604  2
# 3605  2
# 3606  2
# 3607  2
# 3608  2
#
# [3609 rows x 1 columns]

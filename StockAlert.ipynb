# %%
api_data ='https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=demo'

# %%
import requests

# %%
response = requests.get('https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=demo')

# %%
print(response.status_code)
# Out:
# 200

# %%
data = response.json()

# %%
Daily_Time_Series = data['Time Series (Daily)']

# %%
Daily_Time_Series_List = [value for(key, value) in Daily_Time_Series.items()]  ## this line need to explain

# %%
yesterday_data = Daily_Time_Series_List[0]

# %%
yesterday_close = yesterday_data['4. close']  ### why i can use yesterday_data[0]

# %%
before_yesterday_data = Daily_Time_Series_List[1]

# %%
before_yesterday_close = before_yesterday_data['4. close']

# %%
gap = float(yesterday_close) - float(before_yesterday_close)

# %%
gap_rate = (gap-float(before_yesterday_close))/100

# %%
round(gap_rate,2)
# Out:
# -1.41

# %%
response = requests.get('https://newsapi.org/v2/everything?q=ibm&from=2022-03-23&sortBy=publishedAt&apiKey=c1792454c4ca46dd9ef549bcdd88b7ed')

# %%
data = response.json()

# %%
article = data['articles']

# %%
three_article = article[:3]

# %%
three_article_title = [f'{article["title"]}' for article in three_article]

# %%
three_article_title
# Out:
# ['磁帶儲存需求反增 \xa0 2021年出貨量增40%',
#  'Gartner: la corsa alle AI sta spingendo il cloud',
#  'In a Word']

# %%
import telegram

# %%
bot = telegram.Bot(token='5375922635:AAGkddUdbqW-n39lf0e1nTet1u9zD1as3AY')

# %%
updates = bot.get_updates()

# %%
print(bot.get_me())
# Out:
# {'first_name': 'StockAlert', 'id': 5375922635, 'is_bot': True, 'can_join_groups': True, 'can_read_all_group_messages': False, 'supports_inline_queries': False, 'username': 'StockAlertzzbot'}

# %%
print(updates[0])
# Out:
# {'message': {'text': 'Hi', 'group_chat_created': False, 'delete_chat_photo': False, 'caption_entities': [], 'entities': [], 'new_chat_photo': [], 'date': 1650706960, 'photo': [], 'channel_chat_created': False, 'message_id': 3, 'supergroup_chat_created': False, 'chat': {'id': 1255080531, 'username': 'Applewatergrape', 'type': 'private', 'first_name': 'Apple'}, 'new_chat_members': [], 'from': {'id': 1255080531, 'is_bot': False, 'username': 'Applewatergrape', 'first_name': 'Apple', 'language_code': 'zh-hans'}}, 'update_id': 272587235}

# %%
if (gap_rate <= 1):
  bot.send_message(text=three_article_title[1], chat_id=1255080531)
